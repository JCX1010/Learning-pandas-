# %% [markdown]
# # Filtering - Using Conditionals to Filter Rows and Columns #

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# display.max_columns and display.max_rows allows us to see all the rows and columns rather than default first and last 5 respectively

# %%
# countries = ['United States' , 'India', 'United Kingdom' , 'Germany', 'Canada']
# filt = df['Country'].isin(countries)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
df['EdLevel']
# Out:
# Respondent
# 1                                Primary/elementary school
# 2        Secondary school (e.g. American high school, G...
# 3                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                 Bachelor’s degree (BA, BS, B.Eng., etc.)
#                                ...
# 88377                            Primary/elementary school
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863                   Professional degree (JD, MD, etc.)
# Name: EdLevel, Length: 88883, dtype: object

# %%
filt1 = df['EdLevel'].str.contains('BA', na= False)
filt1
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: EdLevel, Length: 88883, dtype: bool

# %%
df.loc[filt1]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# ...                                                       ...      ...
# 84539                                                     NaN      Yes
# 86012                                                     NaN      Yes
# 87352                                                     NaN      Yes
# 87386                                                     NaN      Yes
# 87739                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
# for this particular column, does the string in that column contain python?
# Since that column contains Nan(not a number) we need na= False

# %%
filt
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df.loc[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85738                                          NaN      Yes
# 86566                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object
